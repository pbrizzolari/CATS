# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn import linear_model
from sklearn import decomposition
from sklearn.ensemble import RandomForestRegressor
from matplotlib import pyplot

# %%
data = pd.read_csv("../raw_data/train_call.txt", index_col=0, delimiter="\t").transpose()

topInfo = data.iloc[:3]
data = data.iloc[4:].dropna(axis=1)
data
classes = pd.read_csv("../raw_data/train_clinical.txt", delimiter="\t", index_col=0)
classes
data = classes.join(data).set_index("Subgroup").dropna()

# %%
data.describe()
# Out:
#               1          1          1          1          1          1   \
# count  99.000000  99.000000  99.000000  99.000000  99.000000  99.000000
# mean    0.030303  -0.050505  -0.030303   0.010101  -0.030303  -0.040404
# std     0.483494   0.460118   0.461907   0.484346   0.524006   0.493203
# min    -1.000000  -1.000000  -1.000000  -1.000000  -1.000000  -1.000000
# 25%     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 50%     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 75%     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# max     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
#
#               1          1         1          1   ...         10         10  \
# count  99.000000  99.000000  99.00000  99.000000  ...  99.000000  99.000000
# mean   -0.040404  -0.101010  -0.10101  -0.101010  ...  -0.040404  -0.050505
# std     0.513475   0.543889   0.58020   0.524792  ...   0.587614   0.612351
# ...

# %%
rf = RandomForestRegressor(n_estimators=20, random_state=0).fit(data, data.index)
print(rf.predict(data), data.index)
# Out:
# ['HR+' 'HR+' 'Triple Neg' 'Triple Neg' 'HR+' 'HER2+' 'HER2+' 'Triple Neg'
#  'HER2+' 'HR+' 'Triple Neg' 'HER2+' 'HER2+' 'Triple Neg' 'Triple Neg'
#  'HR+' 'HER2+' 'HR+' 'HR+' 'Triple Neg' 'HER2+' 'HR+' 'HER2+' 'HR+'
#  'HER2+' 'HER2+' 'Triple Neg' 'HER2+' 'HR+' 'HR+' 'HER2+' 'HR+' 'HER2+'
#  'HR+' 'HR+' 'Triple Neg' 'Triple Neg' 'Triple Neg' 'HER2+' 'HR+'
#  'Triple Neg' 'HR+' 'Triple Neg' 'HR+' 'Triple Neg' 'HER2+' 'HER2+'
#  'Triple Neg' 'Triple Neg' 'HER2+' 'HR+' 'HR+' 'Triple Neg' 'HR+'
#  'Triple Neg' 'HER2+' 'HER2+' 'Triple Neg' 'HR+' 'HER2+' 'HR+'
#  'Triple Neg' 'HER2+' 'HR+' 'HER2+' 'HR+' 'HER2+' 'HER2+' 'HR+' 'HER2+'
#  'HER2+' 'HR+' 'HR+' 'HR+' 'Triple Neg' 'HER2+' 'Triple Neg' 'HR+'
#  'Triple Neg' 'Triple Neg' 'Triple Neg' 'Triple Neg' 'HR+' 'HER2+' 'HER2+'
#  'HR+' 'Triple Neg' 'Triple Neg' 'Triple Neg' 'Triple Neg' 'HR+'
#  'Triple Neg' 'HR+' 'Triple Neg' 'HER2+' 'HR+' 'HR+' 'HR+' 'HER2+'] Index(['HR+', 'HR+', 'Triple Neg', 'Triple Neg', 'HR+', 'HER2+', 'HER2+',
# ...

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedShuffleSplit
import sklearn.feature_selection as feature_selection

lr = linear_model.LogisticRegression(penalty="l2", max_iter=10000)
sss = StratifiedShuffleSplit(n_splits=3,test_size=1/3)
ssi = StratifiedShuffleSplit(n_splits=10,test_size=1/10)
for i in range(10):
    #this is the outer-outer-loop
    
    for train_index, test_index in sss.split(data,data.index):
        #outerloop
        train_data = data.iloc[train_index]
        test_data = data.iloc[test_index]
        for inner_train_index, inner_test_index in ssi.split(train_data, train_data.index):
            #print(inner_test_index.tolist(), test_index.tolist())
            inner_train_data = train_data.iloc[inner_train_index]
            inner_test_data = train_data.iloc[inner_test_index]
            best_features = feature_selection.SelectKBest(feature_selection.chi2, k=150).fit(inner_train_data+1,inner_train_data.index)
            inner_train_data = inner_train_data.transpose().loc[best_features.get_support()].transpose()
            inner_test_data = inner_test_data.transpose().loc[best_features.get_support()].transpose()
            lr.fit(inner_train_data, inner_train_data.index)
            cm = confusion_matrix(inner_test_data.index, lr.predict(inner_test_data), labels=lr.classes_)
            disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                             display_labels=lr.classes_)
            disp.plot()
# Out:
# C:\Users\NilsS\anaconda3\envs\school\lib\site-packages\sklearn\metrics\_plot\confusion_matrix.py:81: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()

# %%
feature_selection.f_classif(data, data.index)
#data.astype("category")

x = 

topInfo.transpose().iloc[:-1].loc[x.get_support()]
# Out:
#                   Start          End  Nclone
# Chromosome
# 5            68785515.0   68850823.0     9.0
# 5            69274433.0   70345552.0     5.0
# 5            70422297.0   70698794.0     4.0
# 5            70716278.0   70721505.0     2.0
# 5            93328253.0   96508341.0   310.0
# 5           140433878.0  142819410.0   270.0
# 5           142831583.0  149027600.0   525.0
# 5           150148732.0  150201145.0     5.0
# 5           150224239.0  152555267.0   187.0
# 5           152572508.0  153979903.0   115.0
# 5           154006451.0  157875296.0   310.0
# 6            89106148.0   90015649.0    77.0
# 6           113313043.0  113625048.0    12.0
# 6           115539064.0  119256600.0   285.0
# 6           119263604.0  122326220.0   164.0
# 6           122354776.0  122673457.0     8.0
# 6           122710361.0  123097090.0    43.0
# 6           123114345.0  125128655.0   184.0
# 6           125139481.0  126167412.0    78.0
# 6           126178515.0  126234252.0     7.0
# ...

# %%
fit_data = data.transpose().loc[x.get_support()].transpose()
#fit_data = data

lr = linear_model.LogisticRegression(penalty="l2", max_iter=10000).fit(fit_data, data.index)
print(lr.predict(fit_data), data.index)
# Out:
# ['HR+' 'HR+' 'Triple Neg' 'HR+' 'HER2+' 'Triple Neg' 'HER2+' 'HR+' 'HER2+'
#  'HR+' 'Triple Neg' 'HER2+' 'HER2+' 'HR+' 'Triple Neg' 'HR+' 'HER2+' 'HR+'
#  'HR+' 'Triple Neg' 'HER2+' 'HR+' 'HER2+' 'HR+' 'HER2+' 'HER2+'
#  'Triple Neg' 'HER2+' 'HR+' 'HR+' 'HER2+' 'HER2+' 'HER2+' 'HR+' 'HR+'
#  'Triple Neg' 'Triple Neg' 'Triple Neg' 'HER2+' 'HR+' 'HR+' 'HR+' 'HER2+'
#  'HR+' 'HR+' 'HR+' 'HER2+' 'Triple Neg' 'Triple Neg' 'HER2+' 'HR+' 'HR+'
#  'Triple Neg' 'HR+' 'Triple Neg' 'HR+' 'HER2+' 'Triple Neg' 'HR+' 'HER2+'
#  'HR+' 'Triple Neg' 'HER2+' 'HR+' 'HER2+' 'HR+' 'HER2+' 'HER2+' 'HR+'
#  'HER2+' 'HER2+' 'HR+' 'HR+' 'HR+' 'Triple Neg' 'HER2+' 'HR+' 'HR+'
#  'Triple Neg' 'Triple Neg' 'Triple Neg' 'Triple Neg' 'HR+' 'HER2+' 'HER2+'
#  'HR+' 'HER2+' 'Triple Neg' 'Triple Neg' 'Triple Neg' 'HR+' 'Triple Neg'
#  'HR+' 'HER2+' 'HER2+' 'HR+' 'Triple Neg' 'HR+' 'HER2+'] Index(['HR+', 'HR+', 'Triple Neg', 'Triple Neg', 'HR+', 'HER2+', 'HER2+',
# ...

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

predictions = lr.predict(fit_data)
cm = confusion_matrix(data.index, predictions, labels=lr.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                             display_labels=lr.classes_)
disp.plot()
